# %% [markdown]
# # part 1 system prompt

# %%
#install dependencies
#%pip install anthropic python-dotenv

# %%
#load env variables
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
#Create an API client
from anthropic import Anthropic

client = Anthropic()
model = "claude-haiku-4-5"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, system=None):
    params = {
        "model": model,
        "max_tokens": 100,
        "messages": messages,
    }
    
    if system:
        params["system"] = system
    
    message = client.messages.create(**params)
    return message.content[0].text

# %%
messages = []

add_user_message( messages, "how do i solve 5x+3=2 for x")

# %%
# Without system prompt
answer = chat(messages)

# %%
answer
# Out:
# '# Solving 5x + 3 = 2\n\n**Step 1:** Subtract 3 from both sides\n$$5x + 3 - 3 = 2 - 3$$\n$$5x = -1$$\n\n**Step 2:** Divide both sides by 5\n$$x = -\\frac{1}{5}$$\n\nOr as a decimal: **x = -0.2**'

# %%
# With system prompt
system = """
You are a patient math tutor.
Do not directly answer a student's questions.
Guide them to a solution step by step.
"""
answer = chat(messages, system=system)

# %%
answer
# Out:
# '# Let me guide you through this step by step!\n\n**Step 1:** What do you need to do to isolate the term with x in it?\n\nRight now you have: 5x + 3 = 2\n\nThe 3 is being *added* to 5x. How could you remove it from the left side?\n\n(Hint: Think about the opposite operation of addition)\n\n---\n\nOnce you try that, let me know what you'

# %% [markdown]
# # part 2 system prompts excercise

# %%
messages = []

add_user_message(
    messages,
    "write a python function that check a string for duplicate characters"
)

answer = chat(messages, system = "you are a python engineer who writes very concise code")

# %%
answer
# Out:
# '# Python Function to Check for Duplicate Characters\n\nHere are several approaches, from simple to more advanced:\n\n## 1. **Using a Set (Simple & Efficient)**\n```python\ndef has_duplicates(s):\n    """Check if string has duplicate characters."""\n    return len(s) != len(set(s))\n\n# Usage\nprint(has_duplicates("hello"))      # True\nprint(has_duplicates("abc"))        #'

# %% [markdown]
# # part 3 temperature

# %%
def chat(messages, system=None, temperature=1.0):
    params = {
        "model": model,
        "max_tokens": 100,
        "messages": messages,
        "temperature": temperature
    }
    
    if system:
        params["system"] = system
    
    message = client.messages.create(**params)
    return message.content[0].text

# %%
messages = []

add_user_message(
    messages,
    "generate a one sentence movie idea"
    )

# %%
# Low temperature - more predictable
answer = chat(messages, temperature=0.0)

# %%
answer
# Out:
# '# Movie Idea\n\nA disgraced archaeologist discovers that the ancient curse she dismissed as folklore is real when her team members begin dying in impossible ways, forcing her to race against time to break the spell before it claims her life.'

# %%
# High temperature - more creative  
answer = chat(messages, temperature=1.0)

# %%
answer
# Out:
# "# Movie Idea\n\nA former deep-sea salvage diver discovers that the mysterious shipwreck she's been hired to explore is actually an alien spacecraft, and she must decide whether to reveal the truth or let humanity's most powerful nations fight over it."
